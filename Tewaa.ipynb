# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x= np.linspace(-5, 10, 100)
f=lambda t: t**2-5*t+4
y =f(x)
plt.grid (x,y,label = '$x^(2)-5x+4$')
plt.grid()
plt.legend(loc ='upper right')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7208\3620136856.py in <module>
# ----> 1 x= np.linspace(-5, 10, 100)
#       2 f=lambda t: t**2-5*t+4
#       3 y =f(x)
#       4 plt.grid (x,y,label = '$x^(2)-5x+4$')
#       5 plt.grid()
#
# NameError: name 'np' is not defined

# %%
r = np.arange(0,2,0.01)
p = 2 *np.pi*r
p
fig, ax = plt.subplots(subplot_kw = {'projection':'polar'})
ax.plot(p,r)
ax.set_rmax(2)
ax.set_rticks([0.5,1,1.5,2])
ax.set_rlabel_position(-22.5)
ax.grid(True)
ax.set_title("A line plot on a polar axis", va = 'bottom');

# %%
import numpy as np
a = np.linspace(-np.pi,np.pi, 100)
b = np.cos(a)
c = np.sin(a)

# %%
b * c
# Out:
# array([ 1.22464680e-16,  6.32962268e-02,  1.25573994e-01,  1.85831228e-01,
#         2.43098368e-01,  2.96453965e-01,  3.45039506e-01,  3.88073232e-01,
#         4.24862715e-01,  4.54815998e-01,  4.77451121e-01,  4.92403877e-01,
#         4.99433670e-01,  4.98427388e-01,  4.89401223e-01,  4.72500409e-01,
#         4.47996887e-01,  4.16284927e-01,  3.77874787e-01,  3.33384500e-01,
#         2.83529932e-01,  2.29113261e-01,  1.71010072e-01,  1.10155266e-01,
#         4.75280217e-02, -1.58639667e-02, -7.90006980e-02, -1.40866278e-01,
#        -2.00465268e-01, -2.56838696e-01, -3.09079493e-01, -3.56347086e-01,
#        -3.97880920e-01, -4.33012702e-01, -4.61177147e-01, -4.81921079e-01,
#        -4.94910721e-01, -4.99937064e-01, -4.96919232e-01, -4.85905784e-01,
#        -4.67073930e-01, -4.40726682e-01, -4.07287976e-01, -3.67295854e-01,
#        -3.21393805e-01, -2.70320409e-01, -2.14897456e-01, -1.56016723e-01,
# ...

# %%
b @ c
# Out:
# -1.8041124150158794e-16

# %%
() , (2)
# Out:
# ((), 2)

# %%
from scipy.stats import norm
from scipy.integrate import quad
ϕ = norm()

# %%
value, error = quad(ϕ.pdf,-2,2)

# %%
value
# Out:
# 0.9544997361036417

# %%
value,error = quad(ϕ.pdf, -3,3)

# %%
value
# Out:
# 0.9973002039367399

# %%
value,error = quad(ϕ.pdf, -1, 1)

# %%
value
# Out:
# 0.682689492137086

# %%
from sympy import*
x,y = symbols('x,y')

# %%
x+x+x+y
# Out:
# 3*x + y

# %%
expression  = (x+y)**2

# %%
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
solve(x**2-5*x+4)
# Out:
# [1, 4]

# %%
y = x**4 + 5*x**3 - x + 8
# diff(x**4 + 5*x**3- x + 8, x)

# %%
integrate
y = log(x+1) + cos(x)dy with the limits -oo to oo
differentiate(log(x+1) + cos(x), x, (x, -oo, oo))
# Out:
#   File "C:\Users\BELINDA\AppData\Local\Temp\ipykernel_11696\4062329986.py", line 2
#     y = log(x+1) + cos(x)dy with the limits -oo to oo
#                          ^
# SyntaxError: invalid syntax

# %%
15 + 45
# Out:
# 60

# %%
In
# Out:
# ['',
#  "import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as pit\nget_ipython().run_line_magic('matplotlib', 'inline')",
#  "x=np.linspace(-5,10,100)\nf=lambda t: t**2-5t+4\ny =f(x)\nplt.grid(x,y,label='$x^(2)-5x+4$')\nplt.grid()\nplt.legend(loc='upper right')\nplt.xlabel('x')\nplt.ylabel('y')",
#  "x=np.linspace(-5,10,100)\nf=lambda t: t**2-5t+4\ny =f(x)\nplt.grid(x,y,label='$x^(2)-5x+4$')\nplt.grid()\nplt.legend(loc ='upper right')\nplt.xlabel('x')\nplt.ylabel('y')",
#  'r = np,arange(0,2,0.01)\n0 = 2 *np.pi*r\n0\nfig, ax = plt.subplots(subplot_kw = {\'projection\':\'polar\'})\nax.plot(0,r)\nax.set_rmax(2)\nax.set_rticks([0.5,1,1.5,2])\nax.set_rlabel_position(-22.5)\nax.grid(true)\nax.set_title("A line plot on a polar axis", va = \'bottom\')',
# ...

# %%
Out
# Out:
# {9: Text(0.5, 1.0715488215488216, 'A line plot on a polar axis'),
#  13: array([ 1.22464680e-16,  6.32962268e-02,  1.25573994e-01,  1.85831228e-01,
#          2.43098368e-01,  2.96453965e-01,  3.45039506e-01,  3.88073232e-01,
#          4.24862715e-01,  4.54815998e-01,  4.77451121e-01,  4.92403877e-01,
#          4.99433670e-01,  4.98427388e-01,  4.89401223e-01,  4.72500409e-01,
#          4.47996887e-01,  4.16284927e-01,  3.77874787e-01,  3.33384500e-01,
#          2.83529932e-01,  2.29113261e-01,  1.71010072e-01,  1.10155266e-01,
#          4.75280217e-02, -1.58639667e-02, -7.90006980e-02, -1.40866278e-01,
#         -2.00465268e-01, -2.56838696e-01, -3.09079493e-01, -3.56347086e-01,
#         -3.97880920e-01, -4.33012702e-01, -4.61177147e-01, -4.81921079e-01,
#         -4.94910721e-01, -4.99937064e-01, -4.96919232e-01, -4.85905784e-01,
#         -4.67073930e-01, -4.40726682e-01, -4.07287976e-01, -3.67295854e-01,
# ...

# %%
10 = 20
# Out:
#   File "C:\Users\BELINDA\AppData\Local\Temp\ipykernel_11696\2682558333.py", line 1
#     10 = 20
#     ^
# SyntaxError: cannot assign to literal

# %%
*10=10
# Out:
#   File "C:\Users\BELINDA\AppData\Local\Temp\ipykernel_11696\2975699964.py", line 1
#     10=10
#     ^
# SyntaxError: cannot assign to literal

# %%
40==2*20
# Out:
# True

# %%
10 *           20
# Out:
# 200

# %%
10 +       20
# Out:
# 30

# %%
10+20
# Out:
# 30

# %%
10 + 20
# Out:
# 30

# %%
5**4
# Out:
# 625

# %%
5**3 + 2**2
# Out:
# 129

# %%
num = 30 + 40 
num
# Out:
# 70

# %%
num of heights = 2 , 3 
average height = 3.5
# Out:
#   File "C:\Users\BELINDA\AppData\Local\Temp\ipykernel_11696\3447101921.py", line 1
#     num of heights = 2 , 3
#         ^
# SyntaxError: invalid syntax

# %%
sales = 350

# %%
sales
# Out:
# 350

# %%
royalty = 7

# %%
350 * 7
# Out:
# 2450

# %%
revenue= sales * royalty

# %%
revenue
# Out:
# 2450

# %%
import math

def quadratic_equation(a, b, c):
    x1 = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
    x2 = (-b - math.sqrt(b**2 - 4*a*c)) / (2*a)
    return x1, x2

# %%
print(quadratic_equation(1, -3, 2))
# Out:
# (2.0, 1.0)
